# %% [markdown]
# # 1. 导入包

# %%
'''
Python 3.7.7
sklearn 0.23.1
基于逻辑回归预测客户是否购买汽车新车型
'''

# 导入包
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from matplotlib.colors import ListedColormap

# %% [markdown]
# # 2. 导入数据集

# %%
# 导入数据集
dataset = pd.read_csv('Social_Network_Ads.csv')

# %% [markdown]
# # 3. 数据预处理

# %% [markdown]
# ## 3.1 检测缺失值

# %%
# 检测缺失值
null_df = dataset.isnull().sum()

# %% [markdown]
# ## 3.2 生成自变量和因变量

# %%
# 生成自变量和因变量
X = dataset.iloc[:, [2, 3]].values
y = dataset.iloc[:, 4].values

# %% [markdown]
# ## 3.3 查看样本是否均衡

# %%
# 查看样本是否均衡
sample_0 = sum(dataset['Purchased']==0)
sample_1 = sum(dataset['Purchased']==1)
print('不买车的样本占总样本的%.2f' %(sample_0/(sample_0 + sample_1)))
# Out:
# 不买车的样本占总样本的0.64

# %% [markdown]
# ## 3.4 将数据拆分成训练集和测试集

# %%
# 将数据拆分成训练集和测试集，数据比例为3:1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %% [markdown]
# ## 3.5 特征缩放

# %%
# 特征缩放
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # 4. 使用不同的参数构建逻辑回归模型

# %% [markdown]
# ## 4.1 模型1：构建逻辑回归模型并训练模型

# %% [markdown]
# ### 4.1.1 构建逻辑回归模型并训练

# %%
# 使用不同的参数构建逻辑回归模型
# 模型1：构建逻辑回归模型并训练模型（penalty='l2', C=1, class_weight='balanced'）
classifier = LogisticRegression(penalty='l2', C=1, class_weight='balanced', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1, class_weight='balanced', random_state=0)

# %% [markdown]
# ### 4.1.2 预测测试集

# %%
# 预测测试集
y_pred = classifier.predict(X_test)

# %% [markdown]
# ### 4.1.3 得到线性回归的系数和截距

# %%
# 得到线性回归的系数和截距
print('线性回归的系数是：' + str(classifier.coef_)) # 2.22813781 1.21242255
print('线性回归的截距是：' + str(classifier.intercept_)) # -0.47862396
# Out:
# 线性回归的系数是：[[2.22813781 1.21242255]]
# 线性回归的截距是：[-0.47862396]

# %% [markdown]
# ### 4.1.4 生成混淆矩阵

# %%
# 生成混淆矩阵
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[61,  7],
#        [ 4, 28]], dtype=int64)

# %% [markdown]
# ### 4.1.5 可视化测试集的预测结果

# %%
# 可视化测试集的预测结果
plt.figure()
X_set, y_set = X_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('pink', 'limegreen')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                color = ListedColormap(('red', 'green'))(i), label = j)
plt.title('Logistic Regression (Test set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()

# %% [markdown]
# ### 4.1.6 评估模型性能

# %%
# 评估模型性能
print(accuracy_score(y_test, y_pred)) # 0.89
print(confusion_matrix(y_test, y_pred))
# Out:
# 0.89
# [[61  7]
#  [ 4 28]]

# %% [markdown]
# ## 4.2 模型2：构建逻辑回归模型并训练模型

# %%
# 模型2：构建逻辑回归模型并训练模型（solver='liblinear', penalty='l1', C=2, class_weight=None）
classifier = LogisticRegression(solver='liblinear', penalty='l1', C=2, class_weight=None, random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=2, penalty='l1', random_state=0, solver='liblinear')

# %%
# 预测测试集
y_pred = classifier.predict(X_test)

# %%
# 得到线性回归的系数和截距
print('线性回归的系数是：' + str(classifier.coef_)) # 2.20047762 1.17224223
print('线性回归的截距是：' + str(classifier.intercept_)) # -0.97157422
# Out:
# 线性回归的系数是：[[2.20047762 1.17224223]]
# 线性回归的截距是：[-0.97157422]

# %%
# 生成混淆矩阵
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[65,  3],
#        [ 8, 24]], dtype=int64)

# %%
# 可视化测试集的预测结果
plt.figure()
X_set, y_set = X_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('pink', 'limegreen')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                color = ListedColormap(('red', 'green'))(i), label = j)
plt.title('Logistic Regression (Test set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()

# %%
# 评估模型性能
print(accuracy_score(y_test, y_pred)) # 0.89
print(confusion_matrix(y_test, y_pred))
# Out:
# 0.89
# [[65  3]
#  [ 8 24]]

# %% [markdown]
# #### 结论：
# 由上面2个模型可见，不同超参数对模型性能的影响不同
